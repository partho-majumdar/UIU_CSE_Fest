# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./startup_funding.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
df.head()
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
df
df.drop(columns=['Remarks'], inplace=True)

# %%
df.set_index('Sr No', inplace=True)

# %%
df.rename(columns={
    'Date dd/mm/yyyy': 'date',
    'Startup Name': 'startup', 
    'Industry Vertical': 'vertical', 
    'SubVertical': 'subvertical',
    'City  Location': 'city',
    'Investors Name': 'investors',
    'InvestmentnType': 'round',
    'Amount in USD': 'amount'
}, inplace=True)

# %%
df
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue                  NaN
# 3041   29/01/2015                      Graphene                  NaN
# 3042   30/01/2015                Mad Street Den                  NaN
# 3043   30/01/2015                     Simplotel                  NaN
# 3044   31/01/2015              couponmachine.in                  NaN
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
df.info()
df['amount'] = df['amount'].fillna('0')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3044 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3044 non-null   object
#  1   startup      3044 non-null   object
#  2   vertical     2873 non-null   object
#  3   subvertical  2108 non-null   object
#  4   city         2864 non-null   object
#  5   investors    3020 non-null   object
#  6   round        3040 non-null   object
#  7   amount       2084 non-null   object
# dtypes: object(8)
# memory usage: 214.0+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3044 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3044 non-null   object
#  1   startup      3044 non-null   object
#  2   vertical     2873 non-null   object
#  3   subvertical  2108 non-null   object
#  4   city         2864 non-null   object
#  5   investors    3020 non-null   object
#  6   round        3040 non-null   object
#  7   amount       3044 non-null   object
# dtypes: object(8)
# memory usage: 214.0+ KB

# %%
# df['amount'].astype('int')

# %%
df['amount'] = df['amount'].str.replace(",", "")
df['amount'] = df['amount'].str.replace("undisclosed", "0")
df['amount'] = df['amount'].str.replace("unknown", "0")
df['amount'] = df['amount'].str.replace("Undisclosed", "0")
df
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue                  NaN
# 3041   29/01/2015                      Graphene                  NaN
# 3042   30/01/2015                Mad Street Den                  NaN
# 3043   30/01/2015                     Simplotel                  NaN
# 3044   31/01/2015              couponmachine.in                  NaN
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# ...

# %%
df = df[df['amount'].str.isdigit()]

# %%
df['amount'] = df['amount'].astype('float')
df
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_19068\787567178.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amount'] = df['amount'].astype('float')
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue                  NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3029 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3029 non-null   object
#  1   startup      3029 non-null   object
#  2   vertical     2858 non-null   object
#  3   subvertical  2104 non-null   object
#  4   city         2849 non-null   object
#  5   investors    3005 non-null   object
#  6   round        3027 non-null   object
#  7   amount       3029 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 213.0+ KB

# %%
df.head()
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round       amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  200000000.0
# ...

# %%
def to_inr(dollar):
    inr = dollar * 82.5
    return inr / 10000000

# %%
df['amount'] = df['amount'].apply(to_inr)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_19068\2898200987.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amount'] = df['amount'].apply(to_inr)

# %%
df.head()
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round       amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  1650.000000
# ...

# %%
df['date'] = df['date'].str.replace('05/072018', '05/07/2018')

df['date'] = pd.to_datetime(df['date'], errors='coerce', dayfirst=True)
# df['date'].fillna(pd.Timestamp.now(), inplace=True)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_19068\2032776697.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['date'].str.replace('05/072018', '05/07/2018')
# C:\Users\Asus\AppData\Local\Temp\ipykernel_19068\2032776697.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = pd.to_datetime(df['date'], errors='coerce', dayfirst=True)

# %%
# pd.to_datetime(df['date'])
# df[df['date'] == '13/12/2019']
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3029 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3023 non-null   datetime64[ns]
#  1   startup      3029 non-null   object
#  2   vertical     2858 non-null   object
#  3   subvertical  2104 non-null   object
#  4   city         2849 non-null   object
#  5   investors    3005 non-null   object
#  6   round        3027 non-null   object
#  7   amount       3029 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 213.0+ KB
#             date                       startup             vertical  \
# Sr No
# 1     2020-01-09                        BYJU’S               E-Tech
# 2     2020-01-13                        Shuttl       Transportation
# 3     2020-01-09                     Mamaearth           E-commerce
# 4     2020-01-02  https://www.wealthbucket.in/              FinTech
# ...

# %%
df['date'].dt.day
# Out:
# Sr No
# 1        9.0
# 2       13.0
# 3        9.0
# 4        2.0
# 5        2.0
#         ...
# 3040    29.0
# 3041    29.0
# 3042    30.0
# 3043    30.0
# 3044    31.0
# Name: date, Length: 3029, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3029 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3023 non-null   datetime64[ns]
#  1   startup      3029 non-null   object
#  2   vertical     2858 non-null   object
#  3   subvertical  2104 non-null   object
#  4   city         2849 non-null   object
#  5   investors    3005 non-null   object
#  6   round        3027 non-null   object
#  7   amount       3029 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 213.0+ KB

# %%
df = df.dropna(subset=['date', 'startup', 'vertical', 'city', 'investors', 'round', 'amount'])

# %%
df.shape
# Out:
# (2819, 8)

# %%
# df.to_csv("../Project/startup_cleaned.csv", index=False)

# %%
df['investors'].str.split(",")
df['investors'].str.split(",").sum() # there is some duplicate value 
set(df['investors'].str.split(",").sum())
len(set(df['investors'].str.split(",").sum()))
sorted(set(df['investors'].str.split(",").sum()))
# Out:
# ['',
#  ' & Others',
#  ' 100 Co-founders Lab and others.',
#  ' 122 West Ventures',
#  ' 1Crowd',
#  ' 3ONE4 Capital Advisors',
#  ' 3one4 Capital',
#  ' 3one4 Capital Advisors LLP',
#  ' 500 Start-Ups',
#  ' 500 Startups',
#  ' 500 Startups & Other HNIs',
#  ' 50K Ventures & others',
#  ' 91SpringBoard',
#  ' 91springboard',
#  ' ABB Technology Ventures',
#  ' ABCOM Investments',
#  ' AECAL',
#  ' AET Fund',
#  ' AL Nour International Holdings and Mark V Investments',
#  ' ASP Consulting',
#  ' AVN Business Solutions',
#  ' Aarin Capital',
#  ' Aarin Capital & Others',
#  ' Aaruha Technology Fund',
#  ' Abaran Deep',
#  ' Abhai S. Rao',
#  ' Abhay Singhal',
#  ' Abhijit Bhandari',
#  ' Abhinav Patodia',
#  ' Abhinav Sinha',
#  ' Abhishek Acharya',
#  ' Abhishek Goyal',
#  ' Abhishek Gupta',
#  ' Abhishek Jain',
#  ' Abhishekh Goyal',
#  ' Abstract Ventures',
#  ' Abu Farhan Azmi',
#  ' Accel',
#  ' Accel India',
#  ' Accel Partner',
#  ' Accel Partners',
# ...

# %%
df[df['investors'].str.contains("IDG Ventures")].head()[['date', 'startup', 'vertical', 'city', 'round', 'amount']]
# Out:
#             date   startup           vertical       city           round  \
# Sr No
# 102   2019-04-13   Tripoto       Social Media  New Delhi        Series B
# 223   2018-07-30  Cure Fit  Consumer Internet  Bengaluru  Private Equity
# 259   2018-05-02   Bizongo  Consumer Internet     Mumbai  Private Equity
# 310   2018-04-26     POPxo         Technology      Delhi  Private Equity
# 439   2017-12-07   eShakti          Ecommerce    Chennai    Debt Funding
#
#            amount
# Sr No
# 102     29.628844
# 223    990.000000
# 259    181.500000
# 310     45.375000
# 439     18.975000

# %%
df[df['investors'].str.contains("IDG Ventures")].groupby("startup")['amount'].sum().sort_values(ascending=False)
# Out:
# startup
# Cure Fit                 990.000000
# Lenskart                 495.000000
# Bizongo                  206.250000
# CureFit                  206.250000
# Curefit                  123.750000
# Fintellix                123.750000
# Xpressbees               103.125000
# FirstCry.com              82.500000
# Uniphore                  72.600000
# POPxo                     70.950000
# HealthifyMe               49.500000
# \\xc2\\xa0CloudCherry     49.500000
# Sigtuple                  47.850000
# Flyrobe                   43.725000
# Aasaanjobs                41.250000
# RentMojo                  41.250000
# Vayana                    33.000000
# Agrostar                  33.000000
# PlaySimple                33.000000
# Blowhorn                  30.112500
# Tripoto                   29.628844
# Active.ai                 24.750000
# Heckyl                    22.275000
# CreditMantri              20.625000
# eShakti                   18.975000
# POPxo.com                 16.500000
# ...

# %%
df[df['investors'].str.contains("IDG Ventures")].groupby("vertical")['amount'].sum().plot(kind = 'pie')
# Out:
# <Axes: ylabel='amount'>

# %%
df['year'] = df['date'].dt.year
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_19068\343203772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['date'].dt.year

# %%
df[df['investors'].str.contains("IDG Ventures")].groupby('year')['amount'].sum().plot()
# Out:
# <Axes: xlabel='year'>

# %%
# df.to_csv("../Project/startup_cleaned.csv", index=False)

# %%
round(df['amount'].sum())
# Out:
# 296471

# %%
round(df['amount'].max())
# Out:
# 32175

# %%
df[df['amount'] == 32175]
# Out:
#             date           startup        vertical subvertical       city  \
# Sr No
# 61    2019-08-27  Rapido Bike Taxi  Transportation   Bike Taxi  Bengaluru
#
#                 investors     round   amount  year
# Sr No
# 61     Westbridge Capital  Series B  32175.0  2019

# %%
df.groupby('startup')['amount'].max().sort_values(ascending =False).head(1).values[0]
# Out:
# np.float64(32175.0)

# %%
df.groupby('startup')['amount'].sum().mean()
# Out:
# np.float64(129.06885988844147)

# %%
df['startup'].nunique()
# Out:
# 2297

# %%
df['month'] = df['date'].dt.month
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_19068\2161493741.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df['date'].dt.month

# %%
num_of_funding = df.groupby(['year', 'month'])['startup'].count().reset_index()

# %%
temp_df = df.groupby(['year', 'month'])['amount'].sum().reset_index()

# %%
# df.to_csv("../Project/startup_cleaned.csv", index=False)

# %%
temp_df['x_axis'] = temp_df['month'].astype('str') + "-" + temp_df['year'].astype('str')

# %%
temp_df[['amount', 'x_axis']]
# Out:
#           amount   x_axis
# 0    8080.875000   4-2015
# 1    2641.113750   5-2015
# 2    4302.325500   6-2015
# 3   12450.834000   7-2015
# 4    8776.482000   8-2015
# 5   12123.540000   9-2015
# 6    2103.428250  10-2015
# 7    7399.878750  11-2015
# 8    2523.287250  12-2015
# 9    5774.010000   1-2016
# 10   2734.796625   2-2016
# 11   2553.883266   3-2016
# 12   2095.005000   4-2016
# 13   2803.680000   5-2016
# 14   1647.021750   6-2016
# 15   1926.762750   7-2016
# 16   4406.234250   8-2016
# 17   1991.228250   9-2016
# 18   1958.946000  10-2016
# 19   2144.975250  11-2016
# 20   1544.754750  12-2016
# 21   2089.176375   1-2017
# 22   2433.411750   2-2017
# 23  18680.318250   3-2017
# 24   6042.258750   4-2017
# 25  14740.019250   5-2017
# 26   2844.748500   6-2017
# 27   1383.558000   7-2017
# 28  22672.146750   8-2017
# 29   4426.141500   9-2017
# 30   3303.192750  10-2017
# 31   5080.368398  11-2017
# 32   2324.190000  12-2017
# 33   2845.215450   1-2018
# ...
